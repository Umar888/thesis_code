# %%
import csv
from collections import OrderedDict
import urllib.request
import requests


paper = list()
cited_by = list()

def download_file(download_url, filename):
    response = urllib.request.urlopen(download_url)    
    file = open(filename + ".pdf", 'wb')
    file.write(response.read())
    file.close()

    #======read file========
    
with open('/Users/revglue/study/main_work/my_working/data_set/initial_dataset.csv', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        paper.append(row["Paper"])
        cited_by.append(row["Cited-by"])
        line_count += 1
    print(f'Processed {line_count} lines.')

# paper=list(list(dict.fromkeys(paper)))
# cited_by=list(list(dict.fromkeys(cited_by)))
i=0
# for p in paper:
#     url="https://aclanthology.org/"+p+".pdf"
#     i=i+1
#     print(str(i)+": "+url)
#     download_file(url,"/Users/revglue/study/main_work/my_working/dataset_pdf/"+p)
    
    
for p in cited_by:
    url="https://aclanthology.org/"+p+".pdf"
    i=i+1
    print(str(i)+": "+url)
    if i > 598:
        download_file(url,"/Users/revglue/study/main_work/my_working/dataset_pdf/"+p)
# Out:
# Column names are Annotator, Paper, Cited-by, Follow-up
# Processed 631 lines.
# 1: https://aclanthology.org/C00-2140.pdf
# 2: https://aclanthology.org/P02-1057.pdf
# 3: https://aclanthology.org/W09-1118.pdf
# 4: https://aclanthology.org/A00-2017.pdf
# 5: https://aclanthology.org/C00-2099.pdf
# 6: https://aclanthology.org/W04-1505.pdf
# 7: https://aclanthology.org/P99-1033.pdf
# 8: https://aclanthology.org/W06-0202.pdf
# 9: https://aclanthology.org/P01-1006.pdf
# 10: https://aclanthology.org/E12-1072.pdf
# 11: https://aclanthology.org/C02-1130.pdf
# 12: https://aclanthology.org/C04-1077.pdf
# 13: https://aclanthology.org/C08-1021.pdf
# 14: https://aclanthology.org/C08-1124.pdf
# 15: https://aclanthology.org/D08-1080.pdf
# 16: https://aclanthology.org/D09-1032.pdf
# 17: https://aclanthology.org/E09-1062.pdf
# 18: https://aclanthology.org/I08-1016.pdf
# 19: https://aclanthology.org/J10-1003.pdf
# 20: https://aclanthology.org/J11-1001.pdf
# 21: https://aclanthology.org/P02-1058.pdf
# ...
